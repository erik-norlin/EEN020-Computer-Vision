# %%
import numpy as np
from numpy import linalg as LA
from scipy.io import loadmat
import scipy
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.pyplot import cm
import matplotlib as mpl
import cv2
import computer_vision as cv
from tqdm import trange
import time
from get_dataset_info import *
from scipy.spatial.transform import Rotation
import sys

# %matplotlib qt
# %config InlineBackend.figure_format = 'retina'
from matplotlib import rc
rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
rc('text', usetex=True)


def plot_cameras_and_axes(ax, C_list, axis_list, s, valid_idx, col):

    for i in range(np.size(C_list,1)):

        C = C_list[:,i]
        axis = axis_list[:,i]
        ax.plot(C[0], C[1], C[2], 'o', color=col[i],  label='Camera {}'.format(i+1), alpha=0.7)

        x_axis = C[0] + s*axis[0]
        y_axis = C[1] + s*axis[1]
        z_axis = C[2] + s*axis[2]

        ax.plot([x_axis, C[0]], [y_axis, C[1]], [z_axis, C[2]], '-', color=col[i], lw=3, alpha=0.7)

def plot_cameras_and_3D_points(X_arr, C_arr, axis_arr, s, valid_idx, multi=False):
    
    fig = plt.figure(figsize=(12,8))
    ax = plt.axes(projection='3d')
    col = cm.rainbow(np.linspace(0, 1, np.size(C_arr,1)))

    if multi:
        for i in range(len(X_arr)):
            X = X_arr[i]
            ax.plot(X[0], X[1], X[2], '.', color=col[i], ms=0.8)
    else:
        ax.plot(X_arr[0], X_arr[1], X_arr[2], '.', color='magenta', ms=0.4)
    plot_cameras_and_axes(ax, C_arr, axis_arr, s, valid_idx, col)

    ax.set_xlabel(r'$X$')
    ax.set_ylabel(r'$Y$')
    ax.set_zlabel(r'$Z$')
    ax.set_aspect('equal')
    # ax.view_init(elev=-45, azim=-45, roll=180)
    fig.tight_layout()
    plt.legend(loc="lower right")
    plt.show()

def plot_3D_points(X):
    
    fig = plt.figure()
    ax = plt.axes(projection='3d')
    ax.plot(X[0], X[1], X[2], '.', ms=1, color='magenta', label='X')
    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$')
    ax.set_zlabel('$z$')
    ax.set_aspect('equal')
    ax.legend(loc="lower right")
    fig.tight_layout()
    plt.show()

# %%
def compute_rotation_averaging(imgs, init_pair, K, pixel_threshold, plot=False):
    print('\n\n\n### Computing rotation averaging ###\n')

    K_inv = LA.inv(K)
    n_imgs = imgs.shape[0]
    n_camera_pairs = n_imgs-1

    marg = 0.75
    min_its = 0
    max_its = 10000
    scale_its = 4
    alpha = 0.99
    P1 = cv.get_canonical_camera()
    rel_cameras = [P1]

    x1_norm_RA = []
    x2_norm_RA = []
    inliers_RA = []

    for i in range(n_camera_pairs):    
        print('\nCamera pair:', i+1, '/', n_camera_pairs)

        img1 = imgs[i]
        img2 = imgs[i+1]
        x1, x2, _, _ = cv.compute_sift_points(img1, img2, marg, flann=True, verbose=True)
        x1_norm = cv.dehomogenize(K_inv @ x1)
        x2_norm = cv.dehomogenize(K_inv @ x2)
        x1_norm_RA.append(x1_norm)
        x2_norm_RA.append(x2_norm)

        E, inliers = cv.estimate_E_robust(K, x1_norm, x2_norm, min_its, max_its, scale_its, alpha, pixel_threshold, essential_matrix=True, homography=True, verbose=True)
        inliers_RA.append(inliers)

        x1_norm_inliers = x1_norm[:,inliers]
        x2_norm_inliers = x2_norm[:,inliers]

        P2_arr = cv.extract_P_from_E(E)
        X_arr = cv.compute_triangulated_X_from_extracted_P2_solutions(P1, P2_arr, x1_norm_inliers, x2_norm_inliers)
        P2, X = cv.extract_valid_camera_and_points(P1, P2_arr, X_arr, verbose=True)
        rel_cameras.append(P2)

        if plot:
            percentile = 90
            feasable_pts = cv.compute_feasible_points(P1, P2, X, percentile)
            P_arr = np.array([P1, P2])
            C_arr, axis_arr = cv.compute_camera_center_and_normalized_principal_axis(P_arr, multi=True)
            plot_cameras_and_3D_points(X[:,feasable_pts], C_arr, axis_arr, s=1, valid_idx=None, multi=False)

    rel_cameras = np.array(rel_cameras)
    rel_rots = rel_cameras[:,:,:-1]
    abs_rots = cv.compute_absolute_rotations(rel_rots, init_pair[0], verbose=True)
    
    return abs_rots, x1_norm_RA, x2_norm_RA, inliers_RA

# %%
def compute_initial_3D_points(imgs, init_pair, K, pixel_threshold, plot=False):
    print('\n\n\n### Computing initial 3D-points ###\n')

    K_inv = LA.inv(K)
    min_its = 10000
    max_its = 20000
    scale_its = 3
    alpha = 0.99
    marg = 0.75

    x1_init, x2_init, des1_init, des2_init = cv.compute_sift_points(imgs[init_pair[0]], imgs[init_pair[1]], marg, flann=True, verbose=True)
    x1_init_norm = cv.dehomogenize(K_inv @ x1_init)
    x2_init_norm = cv.dehomogenize(K_inv @ x2_init)

    E, inliers = cv.estimate_E_robust(K, x1_init_norm, x2_init_norm, min_its, max_its, scale_its, alpha, pixel_threshold, essential_matrix=True, homography=True, verbose=True)

    x1_init_norm_inliers = x1_init_norm[:,inliers]
    x2_init_norm_inliers = x2_init_norm[:,inliers]
    des1_init_inliers = des1_init[inliers]
    des2_init_inliers = des2_init[inliers]

    P1 = cv.get_canonical_camera()
    P2_arr = cv.extract_P_from_E(E)
    X_arr = cv.compute_triangulated_X_from_extracted_P2_solutions(P1, P2_arr, x1_init_norm_inliers, x2_init_norm_inliers)
    P2, X_init_inliers = cv.extract_valid_camera_and_points(P1, P2_arr, X_arr, verbose=True)

    percentile = 90
    feasible_pts = cv.compute_feasible_points(P1, P2, X_init_inliers, percentile)

    x1_init_norm_feasible_inliers = x1_init_norm_inliers[:,feasible_pts]
    x2_init_norm_feasible_inliers = x2_init_norm_inliers[:,feasible_pts]
    des1_init_feasible_inliers = des1_init_inliers[feasible_pts]
    des2_init_feasible_inliers = des2_init_inliers[feasible_pts]
    X_init_feasible_inliers = X_init_inliers[:,feasible_pts]
    X_init_idx = np.ones(X_init_feasible_inliers.shape[1], dtype=bool)

    if plot:
        plot_3D_points(X_init_feasible_inliers)
    
    return x1_init_norm_feasible_inliers, x2_init_norm_feasible_inliers, des1_init_feasible_inliers, des2_init_feasible_inliers, X_init_feasible_inliers, X_init_idx

# %%
def compute_translation_registration(K, imgs, init_pair, pixel_threshold, abs_rots, x1_init_norm_feasible_inliers, x2_init_norm_feasible_inliers, des1_init_feasible_inliers, X_init_feasible_inliers, X_init_idx, ransac=False):
    print('\n\n\n### Computing translation registration ###\n')

    K_inv = LA.inv(K)
    marg = 0.75
    min_its = 0
    max_its = 10000
    scale_its = 1
    alpha = 0.99

    trans = []
    x_norm_TR = []
    X_idx_TR = []
    inliers_TR = []

    n_imgs = imgs.shape[0]
    valid_cameras = np.ones(n_imgs, dtype=bool)

    for i in range(n_imgs):
        print('\nImage:', i+1, '/', n_imgs)

        if (i != init_pair[1]) and (i != init_pair[0]):
            img2 = imgs[i]            
            _, x2, X_idx = cv.compute_sift_points_TR(x1_init_norm_feasible_inliers, des1_init_feasible_inliers, img2, marg, flann=True, verbose=True)
            x_norm = cv.dehomogenize(K_inv @ x2)
        elif i == init_pair[0]:
            x_norm = x1_init_norm_feasible_inliers
            X_idx = X_init_idx
        elif i == init_pair[1]:
            x_norm = x2_init_norm_feasible_inliers
            X_idx = X_init_idx

        X = X_init_feasible_inliers[:,X_idx]        
        R = abs_rots[i]

        if ransac:
            T, inliers = cv.estimate_T_robust(K, R, X[:-1], x_norm, min_its, max_its, scale_its, alpha, 5*pixel_threshold, DLT1=False, verbose=True)
        else:
            T = cv.estimate_T_DLT_2(R, x_norm, verbose=False)
            inliers = np.ones(x_norm.shape[1], dtype=bool)

        if np.isnan(T[0]):
            valid_cameras[i] = False

        x_norm_TR.append(x_norm)
        X_idx_TR.append(X_idx)
        trans.append(T)
        inliers_TR.append(inliers)
        
    trans = np.array(trans)

    return trans, valid_cameras, x_norm_TR, X_idx_TR, inliers_TR

# %%
def refine_rotations_and_translations(trans, abs_rots, X_init_feasible_inliers, valid_cameras, X_idx_TR, x_norm_TR, inliers_TR):
    print('\n\n\n### Refining translations and rotations ###\n')

    def fun(params, n_valid_cams, xs_norm, X_init, X_idx_TR, inliers_TR, valid_cameras):

        trans = params[:n_valid_cams * 3].reshape((n_valid_cams, 3))
        q_arr = params[n_valid_cams * 3:].reshape((n_valid_cams, 4))
        rots = []

        for i in range(n_valid_cams):
            R = Rotation.from_quat(q_arr[i] / LA.norm(q_arr[i])).as_matrix()
            U, _, VT = LA.svd(R, full_matrices=False)
            R = U @ VT
            rots.append(R)

        xs_proj = []
        t = 0
        for i in range(len(valid_cameras)):

            if valid_cameras[i]:

                X_idx = X_idx_TR[i]
                inliers_T = inliers_TR[i]

                R = rots[t] 
                X = X_init[:,X_idx][:,inliers_T]
                T = trans[t]
                t += 1

                x_proj = cv.dehomogenize(R @ X + T[:,None])
                xs_proj.append(x_proj)
        xs_proj = np.concatenate(xs_proj, 1)

        return (xs_proj - xs_norm).ravel()


    xs_norm = []
    n_trans = trans.shape[0]

    for i in range(n_trans):
        if valid_cameras[i]:
            x_norm = x_norm_TR[i]
            inliers_T = inliers_TR[i]
            xs_norm.append(x_norm[:,inliers_T])
    xs_norm = np.concatenate(xs_norm, 1)

    n_valid_cams = np.sum(valid_cameras)

    q_arr = []
    for i in range(n_trans): # n_imgs
        if valid_cameras[i]:
            R = abs_rots[i]
            q = Rotation.from_matrix(R).as_quat()
            q_arr.append(q)
    q_arr = np.concatenate(q_arr, 0)

    x0 = np.concatenate((trans[valid_cameras].ravel(), q_arr), 0)
    res = scipy.optimize.least_squares(fun, x0, method='lm', args=(n_valid_cams, xs_norm, X_init_feasible_inliers[:-1], X_idx_TR, inliers_TR, valid_cameras))

    trans_opt_valid = res.x[:n_valid_cams * 3].reshape((n_valid_cams, 3))
    q_opt_valid = res.x[n_valid_cams * 3:].reshape((n_valid_cams, 4))

    abs_rots_opt_valid = []
    for i in range(n_valid_cams):
        R = Rotation.from_quat(q_opt_valid[i] / LA.norm(q_opt_valid[i])).as_matrix()
        U, _, VT = LA.svd(R, full_matrices=False)
        R = U @ VT
        abs_rots_opt_valid.append(R)
    abs_rots_opt_valid = np.array(abs_rots_opt_valid)

    trans_opt = []
    abs_rots_opt = []
    t = 0

    for i in range(n_trans): # n_imgs
        if valid_cameras[i]:
            abs_rots_opt.append(abs_rots_opt_valid[t])
            trans_opt.append(trans_opt_valid[t])
            t += 1
        else:
            abs_rots_opt.append(abs_rots[i])
            trans_opt.append(trans[i])
    
    return abs_rots_opt, trans_opt

# %%
def create_cameras(abs_rots, trans):
    cameras = []

    for i in range(len(trans)):
        R = abs_rots[i]
        T = trans[i]
        P = np.column_stack((R, T))
        cameras.append(P)
    cameras = np.array(cameras)
    print('No. cameras:', cameras.shape[0])
    
    return cameras

# %%
def triangulate_final_3D_reconstruction(imgs, K, pixel_threshold, cameras, valid_cameras, inliers_RA, x1_norm_RA, x2_norm_RA):
    print('\n\n\n### Triangulating final 3D-reconstruction ###\n')

    K_inv = LA.inv(K)
    marg = 0.75
    alpha = 0.99

    X_final = []
    valid_idx = []
    n_valid_cameras = np.sum(valid_cameras)

    for i in range(valid_cameras.shape[0]):
        if valid_cameras[i]:
            valid_idx.append(i)
    valid_idx = np.array(valid_idx)
    print('Valid camera indices:', valid_idx)

    for idx in range(n_valid_cameras-1):
        print('\nCamera pair:', idx+1, '/', n_valid_cameras-1)

        i = valid_idx[idx]
        ij = valid_idx[idx+1]
        
        P1 = cameras[i]
        P2 = cameras[ij]

        if i+1 < ij:
            img1 = imgs[i]
            img2 = imgs[ij]
            x1, x2, _, _ = cv.compute_sift_points(img1, img2, marg, flann=True, verbose=True)
            x1_norm = cv.dehomogenize(K_inv @ x1)
            x2_norm = cv.dehomogenize(K_inv @ x2)

            min_its = 0
            max_its = 10000
            scale_its = 1
            E, inliers = cv.estimate_E_robust(K, x1_norm, x2_norm, min_its, max_its, scale_its, alpha, pixel_threshold, essential_matrix=True, homography=True, verbose=True)
        else:
            inliers = inliers_RA[i]
            x1_norm = x1_norm_RA[i]
            x2_norm = x2_norm_RA[i]
        
        x1_norm_inliers = x1_norm[:,inliers]
        x2_norm_inliers = x2_norm[:,inliers]

        percentile = 90
        X_inliers = cv.triangulate_3D_point_DLT(P1, P2, x1_norm_inliers, x2_norm_inliers, verbose=False)
        feasible_pts = cv.compute_feasible_points(P1, P2, X_inliers, percentile, ransac=False)
        X_final.append(X_inliers[:,feasible_pts])

    C_arr, axis_arr = cv.compute_camera_center_and_normalized_principal_axis(cameras[valid_idx], multi=True)
    plot_cameras_and_3D_points(X_final, C_arr, axis_arr, s=0.5, valid_idx=valid_idx, multi=True)

# %%
print('\n\n\n### Initializing ###\n')

data_set = 1
K, img_names, init_pair, pixel_threshold = get_dataset_info(data_set)
K_inv = LA.inv(K)
imgs = cv.load_image(img_names, multi=True)
n_imgs = imgs.shape[0]
n_camera_pairs = n_imgs-1

abs_rots, x1_norm_RA, x2_norm_RA, inliers_RA = compute_rotation_averaging(imgs, init_pair, K, pixel_threshold, plot=False)
x1_init_norm_feasible_inliers, x2_init_norm_feasible_inliers, des1_init_feasible_inliers, des2_init_feasible_inliers, X_init_feasible_inliers, X_init_idx = compute_initial_3D_points(imgs, init_pair, K, pixel_threshold, plot=False)
trans, valid_cameras, x_norm_TR, X_idx_TR, inliers_TR = compute_translation_registration(K, imgs, init_pair, pixel_threshold, abs_rots, x1_init_norm_feasible_inliers, x2_init_norm_feasible_inliers, des1_init_feasible_inliers, X_init_feasible_inliers, X_init_idx, ransac=True)
abs_rots_opt, trans_opt = refine_rotations_and_translations(trans, abs_rots, X_init_feasible_inliers, valid_cameras, X_idx_TR, x_norm_TR, inliers_TR)
# cameras = create_cameras(abs_rots, trans)
cameras = create_cameras(abs_rots_opt, trans_opt)
triangulate_final_3D_reconstruction(imgs, K, pixel_threshold, cameras, valid_cameras, inliers_RA, x1_norm_RA, x2_norm_RA)
# Out:
# ### Initializing ###
# ### Computing rotation averaging ###
#
#
# Camera pair: 1 / 8
# Number of matches: 13407
# Number of good matches: 7271
# Iteration: 1 T_E: 10000 T_H: 10000 epsilon_E: 0.01 epsilon_H: 0 No. inliers: 100 From: E 8-point alg.
# Iteration: 1 T_E: 10000 T_H: 10000 epsilon_E: 0.03 epsilon_H: 0.0 No. inliers: 229 From: H 4-point alg.
# Iteration: 4 T_E: 10000 T_H: 10000 epsilon_E: 0.04 epsilon_H: 0.0 No. inliers: 320 From: E 8-point alg.
# Iteration: 5 T_E: 10000 T_H: 10000 epsilon_E: 0.1 epsilon_H: 0.02 No. inliers: 735 From: H 4-point alg.
# Iteration: 7 T_E: 10000 T_H: 10000 epsilon_E: 0.12 epsilon_H: 0.02 No. inliers: 874 From: E 8-point alg.
# Iteration: 40 T_E: 10000 T_H: 10000 epsilon_E: 0.15 epsilon_H: 0.06 No. inliers: 1109 From: H 4-point alg.
# Iteration: 41 T_E: 10000 T_H: 10000 epsilon_E: 0.16 epsilon_H: 0.06 No. inliers: 1180 From: E 8-point alg.
# Iteration: 86 T_E: 10000 T_H: 10000 epsilon_E: 0.19 epsilon_H: 0.06 No. inliers: 1416 From: E 8-point alg.
# Iteration: 155 T_E: 10000 T_H: 10000 epsilon_E: 0.21 epsilon_H: 0.06 No. inliers: 1544 From: E 8-point alg.
# Iteration: 164 T_E: 10000 T_H: 10000 epsilon_E: 0.23 epsilon_H: 0.06 No. inliers: 1658 From: E 8-point alg.
# Iteration: 256 T_E: 992.0 T_H: 10000 epsilon_E: 0.61 epsilon_H: 0.06 No. inliers: 4414 From: E 8-point alg.
# Bailout at iteration: 992
# No. valid coords for each camera pair: [4414 4414 8828    0]
# Argmax(P2_arr): 2
#
# Camera pair: 2 / 8
# Number of matches: 14696
# Number of good matches: 7930
# Iteration: 1 T_E: 10000 T_H: 10000 epsilon_E: 0.0 epsilon_H: 0 No. inliers: 3 From: E 8-point alg.
# Iteration: 2 T_E: 10000 T_H: 10000 epsilon_E: 0.09 epsilon_H: 0 No. inliers: 750 From: E 8-point alg.
# Iteration: 12 T_E: 10000 T_H: 10000 epsilon_E: 0.1 epsilon_H: 0.01 No. inliers: 757 From: H 4-point alg.
# Iteration: 23 T_E: 10000 T_H: 10000 epsilon_E: 0.11 epsilon_H: 0.01 No. inliers: 848 From: H 4-point alg.
# Iteration: 34 T_E: 10000 T_H: 10000 epsilon_E: 0.14 epsilon_H: 0.01 No. inliers: 1091 From: E 8-point alg.
# Iteration: 40 T_E: 10000 T_H: 10000 epsilon_E: 0.14 epsilon_H: 0.01 No. inliers: 1130 From: E 8-point alg.
# c:\Users\erikn\skola\EEN020-Computer-Vision\project\computer_vision.py:623: RuntimeWarning: divide by zero encountered in scalar divide
#   T = scale * np.ceil(np.log(1-alpha) / np.log(1-epsilon**s))
# Iteration: 82 T_E: 10000 T_H: 10000 epsilon_E: 0.16 epsilon_H: 0.02 No. inliers: 1240 From: H 4-point alg.
# Iteration: 152 T_E: 10000 T_H: 10000 epsilon_E: 0.25 epsilon_H: 0.09 No. inliers: 2016 From: H 4-point alg.
# Iteration: 190 T_E: 10000 T_H: 10000 epsilon_E: 0.29 epsilon_H: 0.09 No. inliers: 2315 From: E 8-point alg.
# Iteration: 1138 T_E: 10000 T_H: 10000 epsilon_E: 0.45 epsilon_H: 0.09 No. inliers: 3549 From: E 8-point alg.
# Iteration: 2157 T_E: 9676.0 T_H: 10000 epsilon_E: 0.46 epsilon_H: 0.09 No. inliers: 3624 From: E 8-point alg.
# Iteration: 3817 T_E: 8248.0 T_H: 10000 epsilon_E: 0.47 epsilon_H: 0.09 No. inliers: 3697 From: E 8-point alg.
# Iteration: 5167 T_E: 1436.0 T_H: 10000 epsilon_E: 0.58 epsilon_H: 0.09 No. inliers: 4598 From: E 8-point alg.
# Bailout at iteration: 5167
# No. valid coords for each camera pair: [4598 4598 9196    0]
# Argmax(P2_arr): 2
#
# Camera pair: 3 / 8
# Number of matches: 14164
# Number of good matches: 7567
# Iteration: 1 T_E: 10000 T_H: 10000 epsilon_E: 0.12 epsilon_H: 0 No. inliers: 874 From: E 8-point alg.
# Iteration: 12 T_E: 10000 T_H: 10000 epsilon_E: 0.12 epsilon_H: 0.04 No. inliers: 887 From: H 4-point alg.
# Iteration: 20 T_E: 10000 T_H: 10000 epsilon_E: 0.17 epsilon_H: 0.12 No. inliers: 1321 From: H 4-point alg.
# Iteration: 66 T_E: 10000 T_H: 10000 epsilon_E: 0.2 epsilon_H: 0.14 No. inliers: 1514 From: H 4-point alg.
# Iteration: 66 T_E: 10000 T_H: 10000 epsilon_E: 0.28 epsilon_H: 0.14 No. inliers: 2139 From: H 4-point alg.
# Iteration: 619 T_E: 10000 T_H: 10000 epsilon_E: 0.35 epsilon_H: 0.16 No. inliers: 2667 From: H 4-point alg.
# Iteration: 1218 T_E: 6184.0 T_H: 500.0 epsilon_E: 0.48 epsilon_H: 0.44 No. inliers: 3657 From: H 4-point alg.
# Bailout at iteration: 1218
# No. valid coords for each camera pair: [3657 3657    2 7312]
# Argmax(P2_arr): 3
#
# Camera pair: 4 / 8
# Number of matches: 13613
# Number of good matches: 7784
# Iteration: 1 T_E: 10000 T_H: 10000 epsilon_E: 0.0 epsilon_H: 0 No. inliers: 3 From: E 8-point alg.
# Iteration: 2 T_E: 10000 T_H: 10000 epsilon_E: 0.06 epsilon_H: 0 No. inliers: 475 From: E 8-point alg.
# Iteration: 4 T_E: 10000 T_H: 10000 epsilon_E: 0.07 epsilon_H: 0 No. inliers: 527 From: E 8-point alg.
# Iteration: 4 T_E: 10000 T_H: 10000 epsilon_E: 0.07 epsilon_H: 0.0 No. inliers: 562 From: H 4-point alg.
# Iteration: 8 T_E: 10000 T_H: 10000 epsilon_E: 0.1 epsilon_H: 0.02 No. inliers: 741 From: H 4-point alg.
# Iteration: 24 T_E: 10000 T_H: 10000 epsilon_E: 0.16 epsilon_H: 0.02 No. inliers: 1273 From: E 8-point alg.
# Iteration: 48 T_E: 10000 T_H: 10000 epsilon_E: 0.21 epsilon_H: 0.02 No. inliers: 1638 From: E 8-point alg.
# Iteration: 108 T_E: 868.0 T_H: 10000 epsilon_E: 0.62 epsilon_H: 0.02 No. inliers: 4804 From: E 8-point alg.
# Bailout at iteration: 868
# No. valid coords for each camera pair: [   0 9608 4804 4804]
# Argmax(P2_arr): 1
#
# Camera pair: 5 / 8
# Number of matches: 14240
# Number of good matches: 7974
# Iteration: 1 T_E: 10000 T_H: 10000 epsilon_E: 0.02 epsilon_H: 0 No. inliers: 163 From: E 8-point alg.
# Iteration: 1 T_E: 10000 T_H: 10000 epsilon_E: 0.04 epsilon_H: 0.0 No. inliers: 358 From: H 4-point alg.
# Iteration: 3 T_E: 10000 T_H: 10000 epsilon_E: 0.05 epsilon_H: 0.0 No. inliers: 412 From: E 8-point alg.
# Iteration: 9 T_E: 10000 T_H: 10000 epsilon_E: 0.06 epsilon_H: 0.0 No. inliers: 498 From: H 4-point alg.
# Iteration: 11 T_E: 10000 T_H: 10000 epsilon_E: 0.14 epsilon_H: 0.05 No. inliers: 1134 From: H 4-point alg.
# Iteration: 27 T_E: 10000 T_H: 10000 epsilon_E: 0.26 epsilon_H: 0.05 No. inliers: 2062 From: E 8-point alg.
# Iteration: 42 T_E: 10000 T_H: 10000 epsilon_E: 0.33 epsilon_H: 0.05 No. inliers: 2607 From: E 8-point alg.
# Iteration: 188 T_E: 184.0 T_H: 10000 epsilon_E: 0.75 epsilon_H: 0.05 No. inliers: 5947 From: E 8-point alg.
# Bailout at iteration: 188
# No. valid coords for each camera pair: [ 5947  5947 11894     0]
# Argmax(P2_arr): 2
#
# Camera pair: 6 / 8
# Number of matches: 14615
# Number of good matches: 7994
# Iteration: 1 T_E: 10000 T_H: 10000 epsilon_E: 0.01 epsilon_H: 0 No. inliers: 93 From: E 8-point alg.
# Iteration: 1 T_E: 10000 T_H: 10000 epsilon_E: 0.01 epsilon_H: 0.0 No. inliers: 116 From: H 4-point alg.
# Iteration: 1 T_E: 10000 T_H: 10000 epsilon_E: 0.16 epsilon_H: 0.0 No. inliers: 1294 From: H 4-point alg.
# Iteration: 6 T_E: 10000 T_H: 10000 epsilon_E: 0.27 epsilon_H: 0.0 No. inliers: 2192 From: E 8-point alg.
# Iteration: 26 T_E: 3172.0 T_H: 10000 epsilon_E: 0.53 epsilon_H: 0.19 No. inliers: 4199 From: H 4-point alg.
# Iteration: 271 T_E: 196.0 T_H: 10000 epsilon_E: 0.74 epsilon_H: 0.19 No. inliers: 5919 From: E 8-point alg.
# Bailout at iteration: 271
# No. valid coords for each camera pair: [ 5919  5919 11838     0]
# Argmax(P2_arr): 2
#
# Camera pair: 7 / 8
# Number of matches: 14937
# Number of good matches: 7890
# Iteration: 2 T_E: 10000 T_H: 10000 epsilon_E: 0.05 epsilon_H: 0 No. inliers: 361 From: E 8-point alg.
# Iteration: 2 T_E: 10000 T_H: 10000 epsilon_E: 0.09 epsilon_H: 0.02 No. inliers: 720 From: H 4-point alg.
# Iteration: 10 T_E: 10000 T_H: 10000 epsilon_E: 0.13 epsilon_H: 0.02 No. inliers: 1016 From: E 8-point alg.
# Iteration: 13 T_E: 10000 T_H: 10000 epsilon_E: 0.14 epsilon_H: 0.03 No. inliers: 1115 From: H 4-point alg.
# Iteration: 22 T_E: 10000 T_H: 10000 epsilon_E: 0.31 epsilon_H: 0.03 No. inliers: 2444 From: E 8-point alg.
# Iteration: 240 T_E: 10000 T_H: 10000 epsilon_E: 0.36 epsilon_H: 0.03 No. inliers: 2831 From: E 8-point alg.
# Iteration: 362 T_E: 1628.0 T_H: 10000 epsilon_E: 0.57 epsilon_H: 0.03 No. inliers: 4504 From: E 8-point alg.
# Iteration: 1397 T_E: 128.0 T_H: 10000 epsilon_E: 0.78 epsilon_H: 0.03 No. inliers: 6153 From: E 8-point alg.
# Bailout at iteration: 1397
# No. valid coords for each camera pair: [ 6153  6153 12306     0]
# Argmax(P2_arr): 2
#
# Camera pair: 8 / 8
# Number of matches: 15167
# Number of good matches: 7726
# Iteration: 1 T_E: 10000 T_H: 10000 epsilon_E: 0.01 epsilon_H: 0 No. inliers: 67 From: E 8-point alg.
# Iteration: 1 T_E: 10000 T_H: 10000 epsilon_E: 0.01 epsilon_H: 0.0 No. inliers: 73 From: H 4-point alg.
# Iteration: 2 T_E: 10000 T_H: 10000 epsilon_E: 0.05 epsilon_H: 0.0 No. inliers: 389 From: H 4-point alg.
# Iteration: 4 T_E: 10000 T_H: 10000 epsilon_E: 0.06 epsilon_H: 0.0 No. inliers: 501 From: H 4-point alg.
# Iteration: 7 T_E: 10000 T_H: 10000 epsilon_E: 0.18 epsilon_H: 0.08 No. inliers: 1414 From: H 4-point alg.
# Iteration: 26 T_E: 10000 T_H: 10000 epsilon_E: 0.24 epsilon_H: 0.08 No. inliers: 1871 From: E 8-point alg.
# Iteration: 40 T_E: 1612.0 T_H: 10000 epsilon_E: 0.57 epsilon_H: 0.08 No. inliers: 4415 From: E 8-point alg.
# Iteration: 163 T_E: 80.0 T_H: 10000 epsilon_E: 0.82 epsilon_H: 0.08 No. inliers: 6349 From: E 8-point alg.
# Bailout at iteration: 163
# No. valid coords for each camera pair: [    0 12698  6349  6349]
# Argmax(P2_arr): 1
# det(R0): 1.0
# det(R1): 1.0000000000000007
# det(R2): 1.0000000000000007
# det(R3): 1.0000000000000004
# det(R4): 1.0000000000000004
# det(R5): 1.0000000000000004
# det(R6): 1.0000000000000004
# det(R7): 1.0
# det(R8): 1.0000000000000002
#
#
#
# ### Computing initial 3D-points ###
#
# Number of matches: 13407
# Number of good matches: 2172
# Iteration: 2 T_E: 20000 T_H: 20000 epsilon_E: 0.01 epsilon_H: 0 No. inliers: 15 From: E 8-point alg.
# Iteration: 2 T_E: 20000 T_H: 20000 epsilon_E: 0.01 epsilon_H: 0.0 No. inliers: 24 From: H 4-point alg.
# Iteration: 4 T_E: 20000 T_H: 20000 epsilon_E: 0.02 epsilon_H: 0.0 No. inliers: 35 From: E 8-point alg.
# Iteration: 4 T_E: 20000 T_H: 20000 epsilon_E: 0.05 epsilon_H: 0.0 No. inliers: 102 From: H 4-point alg.
# Iteration: 67 T_E: 20000 T_H: 20000 epsilon_E: 0.05 epsilon_H: 0.02 No. inliers: 115 From: H 4-point alg.
# Iteration: 175 T_E: 20000 T_H: 20000 epsilon_E: 0.06 epsilon_H: 0.03 No. inliers: 136 From: H 4-point alg.
# Iteration: 175 T_E: 20000 T_H: 20000 epsilon_E: 0.08 epsilon_H: 0.03 No. inliers: 183 From: H 4-point alg.
# Iteration: 281 T_E: 20000 T_H: 20000 epsilon_E: 0.18 epsilon_H: 0.05 No. inliers: 388 From: H 4-point alg.
# Iteration: 1186 T_E: 20000 T_H: 20000 epsilon_E: 0.21 epsilon_H: 0.05 No. inliers: 448 From: H 4-point alg.
# Iteration: 3390 T_E: 20000 T_H: 20000 epsilon_E: 0.23 epsilon_H: 0.07 No. inliers: 501 From: H 4-point alg.
# Iteration: 3948 T_E: 20000 T_H: 20000 epsilon_E: 0.24 epsilon_H: 0.12 No. inliers: 512 From: H 4-point alg.
# Bailout at iteration: 20000
# No. valid coords for each camera pair: [ 512  512    0 1024]
# Argmax(P2_arr): 3
#
#
#
# ### Computing translation registration ###
#
#
# Image: 1 / 9
# Iteration: 52 T: 10000 epsilon: 0.0 No. inliers: 1
# Iteration: 377 T: 10000 epsilon: 0.0 No. inliers: 2
# Iteration: 383 T: 10000 epsilon: 0.01 No. inliers: 4
# Iteration: 583 T: 10000 epsilon: 0.02 No. inliers: 9
# Iteration: 1806 T: 8052.0 epsilon: 0.02 No. inliers: 11
# Bailout at iteration: 8052
#
# Image: 2 / 9
# Number of matches: 460
# Number of good matches: 366
# Iteration: 56 T: 10000 epsilon: 0.01 No. inliers: 2
# Iteration: 1092 T: 10000 epsilon: 0.01 No. inliers: 3
# Iteration: 3711 T: 10000 epsilon: 0.01 No. inliers: 4
# Iteration: 6398 T: 10000 epsilon: 0.02 No. inliers: 6
# Bailout at iteration: 10000
#
# Image: 3 / 9
# Number of matches: 460
# Number of good matches: 374
# Iteration: 72 T: 10000 epsilon: 0.0 No. inliers: 1
# Iteration: 108 T: 10000 epsilon: 0.01 No. inliers: 5
# Bailout at iteration: 10000
#
# Image: 4 / 9
# Number of matches: 460
# Number of good matches: 353
# Iteration: 237 T: 10000 epsilon: 0.0 No. inliers: 1
# Iteration: 376 T: 10000 epsilon: 0.01 No. inliers: 2
# Iteration: 818 T: 10000 epsilon: 0.01 No. inliers: 3
# Iteration: 3658 T: 10000 epsilon: 0.01 No. inliers: 4
# Bailout at iteration: 10000
#
# Image: 5 / 9
# Number of matches: 460
# Number of good matches: 363
# Iteration: 321 T: 10000 epsilon: 0.01 No. inliers: 2
# Iteration: 907 T: 10000 epsilon: 0.01 No. inliers: 5
# Bailout at iteration: 10000
#
# Image: 6 / 9
# Number of matches: 460
# Number of good matches: 365
# Iteration: 10 T: 10000 epsilon: 0.0 No. inliers: 1
# Iteration: 345 T: 10000 epsilon: 0.01 No. inliers: 2
# Iteration: 1196 T: 10000 epsilon: 0.01 No. inliers: 4
# Iteration: 1831 T: 10000 epsilon: 0.02 No. inliers: 7
# Iteration: 6435 T: 6133.0 epsilon: 0.03 No. inliers: 10
# Bailout at iteration: 6435
#
# Image: 7 / 9
# Number of matches: 460
# Number of good matches: 350
# Iteration: 64 T: 10000 epsilon: 0.01 No. inliers: 2
# Iteration: 801 T: 1164.0 epsilon: 0.06 No. inliers: 22
# Bailout at iteration: 1164
#
# Image: 8 / 9
# Number of matches: 460
# Number of good matches: 329
# Bailout at iteration: 10000
#
# Image: 9 / 9
# Bailout at iteration: 10000
#
#
#
# ### Refining translations and rotations ###
#
# No. cameras: 9
#
#
#
# ### Triangulating final 3D-reconstruction ###
#
# Valid camera indices: [0 1 2 3 4 5 6]
#
# Camera pair: 1 / 6
#
# Camera pair: 2 / 6
#
# Camera pair: 3 / 6
#
# Camera pair: 4 / 6
#
# Camera pair: 5 / 6
#
# Camera pair: 6 / 6
